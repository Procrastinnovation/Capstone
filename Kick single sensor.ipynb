# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

with open('C:\\Users\\kor3a\\Documents\\STM workspace\\20200223_151716_Accelerometer.csv', newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Logged started on', '23/02/2020 15:17:16']
# ['Feature', 'Accelerometer']
# ['Nodes', 'AM1V310 @312248']
# []
# ['Date', 'HostTimestamp', 'NodeName', 'NodeTimestamp', 'RawData', 'X (mg)', 'Y (mg)', 'Z (mg)']
# ['23/02/2020 15:18:59.376', '102428', 'AM1V310 @312248', '15073', 'E8FAE702D502', '-1304', '743', '725']
# ['23/02/2020 15:18:59.465', '102511', 'AM1V310 @312248', '15079', '0CFB2B00F5FF', '-1268', '43', '-11']
# ['23/02/2020 15:18:59.496', '102542', 'AM1V310 @312248', '15086', 'F7FB8EFEA6FF', '-1033', '-370', '-90']
# ['23/02/2020 15:18:59.526', '102572', 'AM1V310 @312248', '15092', 'B6FC53FE8AFF', '-842', '-429', '-118']
# ['23/02/2020 15:18:59.586', '102631', 'AM1V310 @312248', '15098', 'FEFDA6FE8A00', '-514', '-346', '138']
# ['23/02/2020 15:18:59.616', '102661', 'AM1V310 @312248', '15104', 'FCFD70F896FF', '-516', '-1936', '-106']
# ['23/02/2020 15:18:59.676', '102721', 'AM1V310 @312248', '15111', '77F98900D800', '-1673', '137', '216']
# ...

# %%
data = pd.read_csv('C:\\Users\\kor3a\\Documents\\STM workspace\\20200223_151716_Accelerometer.csv', delimiter=';', header=3)

# %%
df = pd.DataFrame(data)

# %%
df[['X (mg)']]
# Out:
#     Date,HostTimestamp,NodeName,NodeTimestamp,RawData,X (mg),Y (mg),Z (mg)
# 0    23/02/2020 15:18:59.376,102428,AM1V310 @312248...
# 1    23/02/2020 15:18:59.465,102511,AM1V310 @312248...
# 2    23/02/2020 15:18:59.496,102542,AM1V310 @312248...
# 3    23/02/2020 15:18:59.526,102572,AM1V310 @312248...
# 4    23/02/2020 15:18:59.586,102631,AM1V310 @312248...
# ..                                                 ...
# 641  23/02/2020 15:19:35.171,138216,AM1V310 @312248...
# 642  23/02/2020 15:19:35.225,138270,AM1V310 @312248...
# 643  23/02/2020 15:19:35.285,138331,AM1V310 @312248...
# 644  23/02/2020 15:19:35.306,138352,AM1V310 @312248...
# 645  23/02/2020 15:19:35.555,138601,AM1V310 @312248...
#
# [646 rows x 1 columns]
